# %%
print("Hello Pakistan")
# Out:
# Hello Pakistan

# %%
print("Python")
# Out:
# Python

# %% [markdown]
# We are learning python for data analysis

# %% [raw]
# Hello python

# %% [markdown]
# # Python

# %% [markdown]
# ![Screenshot%20%2873%29.png](attachment:Screenshot%20%2873%29.png)

# %%
print("Pakistan")
# Out:
# Pakistan

# %%
print("GoogleLab")
# Out:
# GoogleLab

# %% [markdown]
# # Translators
#  - interpreter
#  - compiler

# %% [markdown]
# Python: high level language  >>> human readable and understandable

# %% [markdown]
# System: machine language >>>>  0 1

# %% [markdown]
# Python: is an intpreted language

# %%
print(3)
print("Nasir")
Print(100)

print("Hello")
# Out:
# 3
# Nasir
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-366a306e3086> in <module>
#       1 print(3)
#       2 print("Nasir")
# ----> 3 Print(100)
#       4
#       5 print("Hello")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# # Lets Start Python!!!!!!!!!!!!!!

# %% [markdown]
# Statement / functions  () >>> its a function
# function works for us

# %%
print(4)
#comments
#
# Out:
# 4

# %%
print("nasir", 2,4.5, False)  # string
# Out:
# nasir 2 4.5

# %%
print("We are Pythonis", "Great Learning" ,sep="<><><><><>")   # shift + taB   >>> OPEN signature/ documents
# Out:
# We are Pythonis<><><><><>Great Learning

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
# ?print

# %%
print("I am learning Python")
print("We are in class now")
# Out:
# I am learning Python
# We are in class now

# %%
print("I am learning Python", end="")
print("We are in class now")
# Out:
# I am learning PythonWe are in class now

# %% [markdown]
# # Escape Characters
#   - \n
#   - \t
#   - \r
#   - \b

# %%
print("I am learning\nPython")
# Out:
# I am learning
# Python

# %%
print("I am learning \tPython")
# Out:
# I am learning 	Python

# %% [markdown]
# # String
#   - if some data is in "" that is string
#   - if some data is in '' that is string

# %%
print('I am learning \tPython')
# Out:
# I am learning 	Python

# %%
print('100')
# Out:
# 100

# %% [raw]
# This is "Pakistan", my beloved country

# %%
print("This is "Pakistan",my beloved country")
# Out:
#   File "<ipython-input-25-cce5c1c3a2db>", line 1
#     print("This is "Pakistan",my beloved country")
#                            ^
# SyntaxError: invalid syntax

# %%
print('This is "Pakistan",my beloved country')
# Out:
# This is "Pakistan",my beloved country

# %%
print("This is 'Pakistan',my beloved country")
# Out:
# This is 'Pakistan',my beloved country

# %%
print("This is \"Pakistan\",my beloved country")
# Out:
# This is "Pakistan",my beloved country

# %%
print('This is \'Pakistan\',my beloved country')
# Out:
# This is 'Pakistan',my beloved country

# %% [markdown]
# # Variables

# %%
student = "Muhmmad Ali"
#A string value Muhammad Ali is assigment to a variable(identifier) student

# %%
student
# Out:
# 'Muhmmad Ali'

# %%
firstname = "Nasir"
lastname = "Hussain"

# %%
firstname
# Out:
# 'Nasir'

# %%
lastname
# Out:
# 'Hussain'

# %%
print( type(firstname)        )
# Out:
# <class 'str'>

# %%
print(id(firstname))
# Out:
# 1716358790832

# %%
firstname +" " +lastname

# String concatenation
# Out:
# 'Nasir Hussain'

# %%
# Out:
# 'Nasir Hussain '

# %%
"firstname"
# Out:
# 'firstname'

# %%
firstname
# Out:
# 'Nasir'

# %%
print(firstname)
# Out:
# Nasir

# %%
firstname
print("Hello")
# Out:
# Hello

# %%
"Ahmed"
# Out:
# 'Ahmed'

# %% [markdown]
# # String formation

# %%
description = "My name is "+name+ "and my father name is "+fatherName
print(description)

# string concatenation
# Out:
# My name is Nasir Hussainand my father name is Abdul Latif

# %%
# strig formation

name = "Nasir Hussain"
fatherName = "Abdul Latif"

description = "My name is {} and my father name is {}".format(name,fatherName)
#placeholder
print(description)
# Out:
# My name is Nasir Hussain and my father name is Abdul Latif

# %%
description = f"My name is {name} and my father name is {fatherName}"
print(description)
# Out:
# My name is Nasir Hussain and my father name is Abdul Latif

# %%
print(""" nasir


hussain 


python""")
# Out:
#  nasir
#
#
# hussain
#
#
# python

# %%
roll = "12345"
course ="DA"

# %%
card = f"""
Name: {name}
FatherName: {fatherName}
roll: {roll}
Course: {course}
"""
print(card)
# Out:
# Name: Nasir Hussain
# FatherName: Abdul Latif
# roll: 12345
# Course: DA

# %%
name
# Out:
# 'Nasir Hussain'

# %%
Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-da845b228b4c> in <module>
# ----> 1 Name
#
# NameError: name 'Name' is not defined

# %%
age  = 50

# %%
age
# Out:
# 50

# %%
Age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f798102fc000> in <module>
# ----> 1 Age
#
# NameError: name 'Age' is not defined
